# %% [markdown]
# # **Feature Engineering e Preparação dos Dados**
#
# Nesta etapa, os dados são preparados para modelagem preditiva,
# incluindo a definição da variável alvo e a separação entre
# variáveis numéricas e categóricas.
#
# -----------------------------
#
# ## **1. Importações**

# %%
import sys
import os
import warnings
import pandas as pd

warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
sys.path.append(os.path.abspath("../src"))

import pandas as pd
from feature_engineering import preparar_features

# %% [markdown]
# ## **2. Carregar Dados**

# %%
df = pd.read_csv("../data/raw/telco_churn.csv")

# %% [markdown]
# ## **3. Aplicar Feature Engineering**

# %%
X, y, num_cols, cat_cols = preparar_features(df)

print("Variáveis numéricas:", num_cols)
print("Variáveis categóricas:", cat_cols)
# Out:
# Variáveis numéricas: ['seniorcitizen', 'tenure', 'monthlycharges', 'totalcharges', 'churn']
# Variáveis categóricas: ['gender', 'partner', 'dependents', 'phoneservice', 'multiplelines', 'internetservice', 'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport', 'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling', 'paymentmethod']

# %%
X.head()
# Out:
#    seniorcitizen  tenure  monthlycharges  totalcharges  gender partner  \
# 0              0       1           29.85         29.85  Female     Yes
# 1              0      34           56.95       1889.50    Male      No
# 2              0       2           53.85        108.15    Male      No
# 3              0      45           42.30       1840.75    Male      No
# 4              0       2           70.70        151.65  Female      No
#
#   dependents phoneservice     multiplelines internetservice onlinesecurity  \
# 0         No           No  No phone service             DSL             No
# 1         No          Yes                No             DSL            Yes
# 2         No          Yes                No             DSL            Yes
# 3         No           No  No phone service             DSL            Yes
# 4         No          Yes                No     Fiber optic             No
#
#   onlinebackup deviceprotection techsupport streamingtv streamingmovies  \
# ...
